# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
patents_df = pd.read_csv('../data/raw/SYB66_264_202310_Patents.csv', encoding='ISO-8859-1')
patents_df.columns = patents_df.columns.str.lower().str.replace(' ', '_')
patents_df
# Out:
#                       t29                        patents unnamed:_2  \
# 0     Region/Country/Area                            NaN       Year
# 1                       1  Total, all countries or areas       1985
# 2                       1  Total, all countries or areas       1995
# 3                       1  Total, all countries or areas       2005
# 4                       1  Total, all countries or areas       2010
# ...                   ...                            ...        ...
# 1856                  716                       Zimbabwe       2020
# 1857                  716                       Zimbabwe       2021
# 1858                  716                       Zimbabwe       2019
# 1859                  716                       Zimbabwe       2020
# 1860                  716                       Zimbabwe       2021
#
#                       unnamed:_3 unnamed:_4 unnamed:_5  \
# 0                         Series      Value  Footnotes
# ...

# %%
patents_df.columns
# Out:
# Index(['t29', 'patents', 'unnamed:_2', 'unnamed:_3', 'unnamed:_4',
#        'unnamed:_5', 'unnamed:_6'],
#       dtype='object')

# %%
patents_df = patents_df.drop(index=0).reset_index(drop=True)
patents_df = patents_df.rename(columns={
    't29': 'country_code',
    'patents': 'area',
    'unnamed:_2': 'year',
    'unnamed:_3': 'series',
    'unnamed:_4': 'value',
    'unnamed:_5': 'footnotes',
    'unnamed:_6': 'source'
})
patents_df
# Out:
#      country_code                           area  year  \
# 0               1  Total, all countries or areas  2010
# 1               1  Total, all countries or areas  2019
# 2               1  Total, all countries or areas  2020
# 3               1  Total, all countries or areas  2021
# 4               2                         Africa  2005
# ...           ...                            ...   ...
# 1852          716                       Zimbabwe  2020
# 1853          716                       Zimbabwe  2021
# 1854          716                       Zimbabwe  2019
# 1855          716                       Zimbabwe  2020
# 1856          716                       Zimbabwe  2021
#
#                           series      value footnotes  \
# 0     Grants of patents (number)    914,200       NaN
# 1     Grants of patents (number)  1,506,900       NaN
# 2     Grants of patents (number)  1,596,500       NaN
# 3     Grants of patents (number)  1,756,500       NaN
# ...

# %%
patents_df = patents_df.drop(columns= ['footnotes', 'source'])
patents_df
# Out:
#      country_code                           area  year  \
# 0               1  Total, all countries or areas  2010
# 1               1  Total, all countries or areas  2019
# 2               1  Total, all countries or areas  2020
# 3               1  Total, all countries or areas  2021
# 4               2                         Africa  2005
# ...           ...                            ...   ...
# 1852          716                       Zimbabwe  2020
# 1853          716                       Zimbabwe  2021
# 1854          716                       Zimbabwe  2019
# 1855          716                       Zimbabwe  2020
# 1856          716                       Zimbabwe  2021
#
#                           series      value
# 0     Grants of patents (number)    914,200
# 1     Grants of patents (number)  1,506,900
# 2     Grants of patents (number)  1,596,500
# 3     Grants of patents (number)  1,756,500
# 4     Grants of patents (number)      4,200
# ...

# %%
patents_df.isna().sum()
# Out:
# country_code    0
# area            0
# year            0
# series          0
# value           0
# dtype: int64

# %%
patents_df.to_csv('clean_patents_df.csv', index=False)
